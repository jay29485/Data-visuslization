# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jul  8 14:24:12 2022

@author: karun
"""

import numpy as np
import seaborn as sns
import pandas as pd
a=pd.read_csv("C:/Users/karun/OneDrive/Desktop/FA/hpi_data.csv")
print(a.describe())
import matplotlib.pyplot as plt
f=plt.figure()
ax=f.add_subplot(111)
print(a.head())
print(a.columns)
ax=sns.scatterplot(x="Wellbeing (0-10)",y="Happy Planet Index",hue="Country",data=a.head())

plt.show()
print(a)
print(a.columns)

import altair as alt
#print(altair.__file__)
alt.Chart(a).mark_circle().encode(x="Wellbeing (0-10):Q",y="Happy Planet Index:Q",color="Region:N",tooltip=["Wellbeing (0-10):Q"]).interactive()
#alt.Chart(a).mark_circle().encode(x="Wellbeing (0-10)",y="Happy Planet Index",color="Region").interactive()
# Out:
#        Unnamed: 0  HPI Rank  Life Expectancy (years)  Wellbeing (0-10)  \
# count    140.0000  140.0000               140.000000        140.000000
# mean      69.5000   70.5000                70.924286          5.407857
# std       40.5586   40.5586                 8.754048          1.148478
# min        0.0000    1.0000                48.900000          2.900000
# 25%       34.7500   35.7500                65.025000          4.575000
# 50%       69.5000   70.5000                73.500000          5.250000
# 75%      104.2500  105.2500                77.050000          6.225000
# max      139.0000  140.0000                83.600000          7.800000
#
#        Ecological Footprint (gha/capita)  Happy Planet Index
# count                         140.000000          140.000000
# mean                            3.260000           26.407857
# std                             2.303073            7.319404
# min                             0.600000           12.800000
# ...

# %%
sa=alt.selection_interval()
alt.Chart(a.head()).mark_circle().encode(x="Wellbeing (0-10):Q",y="Happy Planet Index:Q",color="Region:N").add_selection(sa)
# Out:
# alt.Chart(...)

# %%
sa=alt.selection_interval()
alt.Chart(a).mark_circle().encode(x="Wellbeing (0-10):Q",y="Happy Planet Index:Q",tooltip=["Wellbeing (0-10):Q"],color=alt.condition(sa,"Region:N",alt.value('lightgray'))).interactive().add_selection(sa)
# Out:
# alt.Chart(...)

# %%
sa=alt.selection_interval()
Chart=alt.Chart(a).mark_circle().encode(x="Wellbeing (0-10):Q",y="Happy Planet Index:Q",tooltip=["Wellbeing (0-10):Q"],color=alt.condition(sa,"Region:N",alt.value('lightgray'))).interactive().add_selection(sa)
chart1=Chart.encode(x="Wellbeing (0-10):Q")
chart2=Chart.encode(y="Happy Planet Index:Q")
alt.hconcat(chart1,chart2)
# Out:
# alt.HConcatChart(...)

# %%
input_dropdown=alt.binding_select(options=list(set(a.Region)))
selected_points=alt.selection_single(fields=['Region'],bind=input_dropdown,name='Select')
color=alt.condition(selected_points,
                   alt.Color('Region:N'),
                   alt.value('lightgray'))
alt.Chart(a).mark_circle().encode(x='Wellbeing(0-10):Q',y='Happy Planet Index:Q',color=color,tooltip='Region:N').add_selection(selected_points)
# Out:
# alt.Chart(...)

# %%
input_dropdown=alt.binding_select(options=list(set(a.Region)))
selected_points=alt.selection_single(fields=['Region'],bind=input_dropdown, name='Select')
color=alt.condition(selected_points,alt.Color('Region:N'),alt.value('lightgray'))
alt.Chart(a).mark_circle().encode(x='Wellbeing (0-10):Q',y='Happy Planet Index:Q',color=color,tooltip='Region:N').add_selection(selected_points)
# Out:
# alt.Chart(...)

# %%
a
# Out:
#      Unnamed: 0  HPI Rank     Country              Region  \
# 0             0         1  Costa Rica            Americas
# 1             1         2      Mexico            Americas
# 2             2         3    Colombia            Americas
# 3             3         4     Vanuatu        Asia Pacific
# 4             4         5     Vietnam        Asia Pacific
# ..          ...       ...         ...                 ...
# 135         135       136    Mongolia        Asia Pacific
# 136         136       137       Benin  Sub Saharan Africa
# 137         137       138        Togo  Sub Saharan Africa
# 138         138       139  Luxembourg              Europe
# 139         139       140        Chad  Sub Saharan Africa
#
#      Life Expectancy (years)  Wellbeing (0-10) Inequality of outcomes  \
# 0                       79.1               7.3                    15%
# 1                       76.4               7.3                    19%
# ...

# %%
sa=alt.selection_interval()
Chart=alt.Chart(a).mark_circle().encode(x="Wellbeing (0-10):Q",y="Happy Planet Index:Q",tooltip=["Wellbeing (0-10):Q"],color=alt.condition(sa,"Region:N",alt.value('lightgray'))).interactive().add_selection(sa)
chart1=Chart.encode(x="Wellbeing (0-10):Q")
chart2=Chart.encode(y="Happy Planet Index:Q")
alt.hconcat(chart1,chart2)
chart1|chart2

# %%
input_dropdown=alt.binding_select(options=list(set(a.Region)))
selected_points=alt.selection_single(fields=['Region'],bind=input_dropdown, name='Select')
color=alt.condition(selected_points,alt.Color('Region:N'),alt.value('lightgray'))
alt.Chart(a).mark_circle().encode(x='Wellbeing (0-10):Q',y='Happy Planet Index:Q',color=color,tooltip='Region:N').add_selection(selected_points)
# Out:
#   File "C:\Users\karun\AppData\Local\Temp/ipykernel_20804/4203632018.py", line 3
#     hm=alt.Chart(a).mark_rect().encode(x='Wellbeing (0-10):Q ',bin=True),alt.y=('Happy Planet Index:Q',bin=True),alt.color('count()',Scale=alt.Scale(scheme='greenblue'),legend=alt.legend(title="Total countries")).properties(width=350)
#        ^
# SyntaxError: cannot assign to function call

# %%
selected_region=alt.selection(type='single',encodings=['x'])


heatmap=alt.Chart(hpi_df).mark_rect().encode(alt.X('Wellbeing (0-10):Q',bin=True),alt.Y('Life Expectancy (years):Q',bin=True),alt.Color('count()',scale=alt.Scale(scheme='greenblue'),legend=alt.Legend(title='Total Countries'))).properties(width=350)
# Out:
#   File "C:\Users\karun\AppData\Local\Temp/ipykernel_20804/4183966338.py", line 4
#     heatmap=alt.Chart(a.mark_rect().encode(alt.X('Wellbeing (0-10):Q',bin=True),alt.Y('Life Expectancy (years):Q',bin=True),alt.Color('count()',scale=alt.Scale(scheme='greenblue'),legend=alt.Legend(title='Total Countries'))).properties(width=350)
#                                                                                                                                                                                                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
selected_region=alt.selection(type='single',encodings=['x'])


heatmap=alt.Chart(a).mark_rect().encode(alt.X('Wellbeing (0-10):Q',bin=True),alt.Y('Life Expectancy (years):Q',bin=True),alt.Color('count()',scale=alt.Scale(scheme='greenblue'),legend=alt.Legend(title='Total Countries'))).properties(width=350)
